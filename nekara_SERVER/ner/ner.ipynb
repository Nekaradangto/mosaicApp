# %%
# !pip install -r 'ner/requirements.txt'
# Out:
# ...
#      |████████████████████████████████| 753.4 MB 7.2 kB/s eta 0:00:013
# ...
#      |████████████████████████████████| 660 kB 5.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 43 kB 1.3 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 7.5 MB 4.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 78 kB 2.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 764 kB 4.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 3.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 880 kB 4.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 31.2 MB 157 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 306 kB 4.3 MB/s eta 0:00:01
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16170 sha256=bcf920a381ed937b91409d0b5dc834dfaec158f1e5ce104ee3ef85cfae24877e
#   Stored in directory: /home/joohyeson/.cache/pip/wheels/ad/5c/ba/05fa33fa5855777b7d686e843ec07452f22a66a138e290e732
# ...

# %%
cd /content/drive/MyDrive/ner
# Out:
# /content/drive/MyDrive/ner

# %%
# !python3 predict.py
# Out:
# 06/19/2022 20:44:35 - INFO - transformers.configuration_utils -   loading configuration file ./model/config.json
# 06/19/2022 20:44:35 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "architectures": [
#     "BertForTokenClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "naver-ner",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "UNK",
#     "1": "O",
#     "2": "PER-B",
#     "3": "PER-I",
#     "4": "FLD-B",
#     "5": "FLD-I",
#     "6": "AFW-B",
#     "7": "AFW-I",
#     "8": "ORG-B",
#     "9": "ORG-I",
#     "10": "LOC-B",
#     "11": "LOC-I",
#     "12": "CVL-B",
#     "13": "CVL-I",
#     "14": "DAT-B",
#     "15": "DAT-I",
#     "16": "TIM-B",
#     "17": "TIM-I",
#     "18": "NUM-B",
#     "19": "NUM-I",
#     "20": "EVT-B",
#     "21": "EVT-I",
#     "22": "ANM-B",
#     "23": "ANM-I",
#     "24": "PLT-B",
#     "25": "PLT-I",
# ...
